# %%
import requests
import json
from bs4 import BeautifulSoup

# %%
url = "https://www.ptt.cc/bbs/index.html"
path = {"User-Agent" : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36'}
web = requests.get(url, headers=path)
web.encoding = 'uft-8'
print(web.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>熱門看板 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# ...

# %% [markdown]
# 程式碼都對，就是爬不下來

# %%
import json
web = requests.get('https://data.kcg.gov.tw/dataset/6f29f6f4-2549-4473-aa90-bf60d10895dc/resource/30dfc2cf-17b5-4a40-8bb7c511ea166bd3/download/lightrailtraffic.json')
data = json.loads(web.content.decode('utf-8-sig'))
print(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-42-a515b1cae76a> in <cell line: 3>()
#       1 import json
#       2 web = requests.get('https://data.kcg.gov.tw/dataset/6f29f6f4-2549-4473-aa90-bf60d10895dc/resource/30dfc2cf-17b5-4a40-8bb7c511ea166bd3/download/lightrailtraffic.json')
# ----> 3 data = json.loads(web.content.decode('utf-8-sig'))
#       4 print(data)
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# ...

# %% [markdown]
# 捉台灣水庫

# %%
url = 'https://water.taiwanstat.com/'
web = requests.get(url)
soup = BeautifulSoup(web.text, "html.parser")
print(soup)
soup = BeautifulSoup(web.text, "html5lib")
# print(soup)
title = soup.title
# print(title)
# Out:
# <!DOCTYPE html>
# ...

# %%
from bs4 import BeautifulSoup
import requests as rq
#we need to request a web site
url = 'https://water.taiwanstat.com/'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.146 Safari/537.36'}
response = rq.get(url, headers = headers, timeout=2)
html = response.content
#print(html)
soup = BeautifulSoup(html, "html.parser")
# data loaded
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# 捉文字

# %%
soup = BeautifulSoup(html, "html.parser")
for script in soup(["script", "style"]):
  script.extract()
  # get text
  text = soup.get_text()
  # create a new bs4 object from the html data loaded
  # remove all javascript and stylesheet code
  # break into lines and remove leading and trailing space on each
  lines = (line.strip() for line in text.splitlines())
  # break multi-headlines into a line each
  chunks = (phrase.strip() for line in lines for phrase in line.split(" "))
  # drop blank lines
  texts = '\n'.join(chunk for chunk in chunks if chunk)
print(texts)
# Out:
# 台灣水庫即時水情
# 用數據看台灣
# 台灣開放即時資料
# 台灣開放統計資料
# 世界即時資訊
# 世界統計資訊
# 開放資料分析部落格
# 關於我們
# 用數據看台灣
# 台灣開放即時資料
# 台灣開放統計資料
# 世界即時資訊
# 世界統計資訊
# 開放資料分析部落格
# 關於我們
# 台灣水庫即時水情
# 北部
# 中部
# 南部資料來源：經濟部水利署即時水情資料係自記儀器自動產生，未經人工完整檢驗，僅提供參考。根據水利署網頁公布，各項水庫資料由各水庫管理單位在每日輸入，更新時間不一致。（部分水庫星期六、日之資料則在星期一統一輸入）預測剩餘天數
# =
# 即時有效蓄水量/昨日下降蓄水量。因降雨、用水量隨時間變化，預測結果僅提供參考。新山水庫(基隆)
# 7001.1萬立方公尺萬立方公尺更新時間：0000-00-00
# (0時)翡翠水庫(台北、新北)
# 26722.51萬立方公尺萬立方公尺更新時間：0000-00-00
# (0時)石門水庫(新北、桃園、新竹)
# 4025.63萬立方公尺萬立方公尺更新時間：0000-00-00
# (0時)永和山水庫(新竹、苗栗)
# 685.598萬立方公尺萬立方公尺更新時間：0000-00-00
# (0時)寶山水庫(新竹)
# 7001.1萬立方公尺萬立方公尺更新時間：0000-00-00
# (0時)寶山第二水庫(新竹)
# 7001.1萬立方公尺萬立方公尺更新時間：0000-00-00
# (0時)明德水庫(苗栗)
# 262.0316萬立方公尺萬立方公尺更新時間：0000-00-00
# (0時)鯉魚潭水庫(苗栗、台中)
# 9857.34萬立方公尺萬立方公尺更新時間：0000-00-00
# (0時)德基水庫(台中)
# 762.27萬立方公尺萬立方公尺更新時間：0000-00-00
# (0時)石岡壩(台中)
# 11486萬立方公尺萬立方公尺更新時間：0000-00-00
# (0時)日月潭水庫(南投)
# 5741萬立方公尺萬立方公尺更新時間：0000-00-00
# (0時)霧社水庫(南投)
# 3269.4萬立方公尺萬立方公尺更新時間：0000-00-00
# (0時)湖山水庫(雲林、彰化、嘉義)
# 820.884613萬立方公尺萬立方公尺更新時間：0000-00-00
# ...

# %% [markdown]
# 捉PTT標題和連結

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.ptt.cc/'
web = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html',cookies={'over18':'1'})
soup = BeautifulSoup(web.text, "html.parser")
titles = soup.find_all('div', class_='title')
for i in titles:
  if i.find('a') != None:
    print(i.find('a').get_text())
    # 使用get_text() 取得文字
    # 取得class 為title
    # 判斷如果不為None
    # 取得 div 裡 a 的內容，
    print(url + i.find('a')['href'], end='\n\n')  # 使用 ['href'] 取得href 的屬性
# Out:
# Re: [爆卦] 俄羅斯向烏克蘭發射洲際彈道飛彈（ICBM）
# https://www.ptt.cc//bbs/Gossiping/M.1732178993.A.28A.html
#
# [問卦] 政府是不是維持最基本功能就好
# https://www.ptt.cc//bbs/Gossiping/M.1732179008.A.E96.html
#
# [問卦] 洲際彈道飛彈 飛到太空中 還需要警報嗎?
# https://www.ptt.cc//bbs/Gossiping/M.1732179062.A.6D9.html
#
# [問卦] 內雙的人是不是有時候會變外雙
# https://www.ptt.cc//bbs/Gossiping/M.1732179084.A.B21.html
#
# Re: [問卦] 數發部弄這衝三小？
# https://www.ptt.cc//bbs/Gossiping/M.1732179103.A.65B.html
#
# [問卦] 台積一堆謝等級的主管真的假的？
# https://www.ptt.cc//bbs/Gossiping/M.1732179161.A.D72.html
#
# 謝遺容的年薪
# https://www.ptt.cc//bbs/Gossiping/M.1732179329.A.37D.html
#
# [問卦] 文組想問 AI伺服器 跟楓之谷伺服器一樣嗎？
# https://www.ptt.cc//bbs/Gossiping/M.1732179355.A.E74.html
#
# [問卦] 如果用海參崴換基輔 值得嗎
# https://www.ptt.cc//bbs/Gossiping/M.1732179400.A.CCD.html
#
# [問卦] 謝宜容跟虐死凱凱保母 長相有像嗎
# https://www.ptt.cc//bbs/Gossiping/M.1732179430.A.A44.html
#
# [問卦] 烏克蘭會被種香菇嗎？
# https://www.ptt.cc//bbs/Gossiping/M.1732179447.A.4A8.html
#
# [問卦] 現實中  你敢惹宜容嗎？  就問一句
# ...

# %% [markdown]
# 捉.jpg

# %%
import requests
from bs4 import BeautifulSoup
web = requests.get('https://www.ptt.cc/bbs/Beauty/M.1732098889.A.713.html', cookies={'over18':'1'}) #傳送 Cookies 資訊後，抓取頁面內容
soup = BeautifulSoup(web.text, "html.parser") #使用BeautifulSoup 取得網頁結構

imgs = soup.find_all('img') #取得所有 img tag 的內容
for i in imgs:
  print(i['src'])
# Out:
# https://cache.ptt.cc/c/https/i.imgur.com/BWOCQwkl.jpeg?e=1732355371&s=UtvHgX0TyVPTSpHtNF5seQ
# https://cache.ptt.cc/c/https/i.imgur.com/wviBE7cl.jpeg?e=1732376388&s=Rs5TqX2m9xr7KuOzIRWH6A
# https://cache.ptt.cc/c/https/i.imgur.com/3M5laull.jpeg?e=1732343686&s=wgp8HEf0NFXlZuE_ktVvcw
# https://cache.ptt.cc/c/https/i.imgur.com/BPldKrFl.jpeg?e=1732333452&s=Dlp8qvOZOjNLovyXbyTPYQ
# https://cache.ptt.cc/c/https/i.imgur.com/nwPWYMHl.jpeg?e=1732357529&s=VG8QkCodnXZCkLxYGpCeRg
# https://cache.ptt.cc/c/https/i.imgur.com/9heltLtl.jpeg?e=1732329873&s=Q8XXDjSDrf5iIOQuDYhVug
# https://cache.ptt.cc/c/https/i.imgur.com/EDoPCaPl.jpeg?e=1732365671&s=0swFik5aT_sLf3vdgW1CMw
# https://cache.ptt.cc/c/https/i.imgur.com/ZH2Wv47l.jpeg?e=1732352781&s=BJO1lS8VASoRe0w1e4ju9A
# https://cache.ptt.cc/c/https/i.imgur.com/aw6rrc7l.jpeg?e=1732367333&s=avin0Oyt-1asN55KSKNEyg

# %% [markdown]
# 將.jpg存至雲端硬碟

# %%
import requests
from bs4 import BeautifulSoup
import os
from google.colab import drive
# 挂载Google Drive（可选，如果需要保存到云端硬盘）
drive.mount('/content/drive')
# 定义并创建保存图片的目录
save_dir = '/content/drive/MyDrive/ColabNotebooks/download/'
if not os.path.exists(save_dir):
 os.makedirs(save_dir)

web = requests.get('https://www.ptt.cc/bbs/Beauty/M.1710593264.A.578.html', cookies={'over18':'1'})
soup = BeautifulSoup(web.text, "html.parser")
imgs = soup.find_all('img')
name = 0    # 设定图片编号
for i in imgs:
  print(i['src'])
  jpg = requests.get(i['src'])  # 使用 requests 获取图片内容
  with open(f'{save_dir}test_{name}.jpg', 'wb') as f:
    f.write(jpg.content)  # 写入图片内容
  name += 1  # 编号增加1
# Out:
# Mounted at /content/drive
# https://cache.ptt.cc/c/https/i.imgur.com/zSCKh5fl.jpg?e=1732369864&s=KmjRfK3B_arIFjHokcja1g
# https://cache.ptt.cc/c/https/i.imgur.com/4Xfq2nrl.jpg?e=1732374541&s=EIcX0hS46H0kjswqWvnVcg
# https://cache.ptt.cc/c/https/i.imgur.com/vJIMY03l.jpg?e=1732318836&s=HgNLPDkK1jgoN5umrFwkEw
# https://cache.ptt.cc/c/https/i.imgur.com/wKWzZBfl.jpg?e=1732317043&s=GXppg4TaL4-TvNtsXQInSg
# https://cache.ptt.cc/c/https/i.imgur.com/5a24s64l.jpg?e=1732332807&s=-lS9175ldxcWjB2Wtkx5Bg
# https://cache.ptt.cc/c/https/i.imgur.com/3bPuFPyl.jpg?e=1732357271&s=jiFDOjw3ZgyfYvwo7kiPBw
# https://cache.ptt.cc/c/https/i.imgur.com/FfVPpXyl.jpg?e=1732331817&s=WQQv0A8Gp-a6pCdQzZ5eSQ
# https://cache.ptt.cc/c/https/i.imgur.com/jGCMjBil.jpg?e=1732371362&s=NkRn4o0108IJam7KfyK_lg
# https://cache.ptt.cc/c/https/i.imgur.com/jDLMlT9l.jpg?e=1732358656&s=_Sj8dIWJ7hM__skUklJqhQ
# https://cache.ptt.cc/c/https/i.imgur.com/ACsDTnel.jpg?e=1732367376&s=0av-xekOQjj5I_o136sZMQ
# ...

# %% [markdown]
# 捉統一發票

# %%
import requests
url = 'https://invoice.etax.nat.gov.tw/index.html'
web = requests.get(url)    # 取得網頁內容
web.encoding='utf-8'
# 因為該網頁編碼為utf-8，加上.encoding 避免亂碼
from bs4 import BeautifulSoup
soup = BeautifulSoup(web.text, "html.parser")
# 轉換成標籤樹
td = soup.select('.container-fluid')[0].select('.etw-tbiggest')  # 取出中獎號碼的位置
ns = td[0].getText()  # 特別獎
n1 = td[1].getText()  # 特獎
# 頭獎，因為存入串列會出現/n 換行符，使用[-8:] 取出最後八碼
n2 = [td[2].getText()[-8:], td[3].getText()[-8:], td[4].getText()[-8:]]
print(ns)
print(n1)
print(n2)
# Out:
# 38039158
# 08276859
# ['32110911', '84289408', '13446901']

# %%
import requests
url = 'https://rate.bot.com.tw/xrt/flcsv/0/day'   # 牌告匯率 CSV 網址
rate = requests.get(url)   # 爬取網址內容
rate.encoding = 'utf-8'    # 調整回應訊息編碼為 utf-8，避免編碼不同造成亂碼
rt = rate.text
rts = rt.split('\n')
for i in rts:
  try:
    a = i.split(',')
    # 以文字模式讀取內容
      # 使用「換行」將內容拆分成串列
      # 讀取串列的每個項目
    # 使用try 避開最後一行的空白行
      # 每個項目用逗號拆分成子串列
    print(a[0] + ': ' + a[12])   # 取出第一個 ( 0 ) 和第十三個項目 ( 12 )
  except:
    break
# Out:
# ﻿幣別: 現金
# USD: 32.81500
# HKD: 4.23000
# GBP: 42.06000
# AUD: 21.58000
# CAD: 23.71000
# SGD: 24.56000
# CHF: 37.21000
# JPY: 0.21450
# ZAR: 0.00000
# SEK: 0.00000
# NZD: 19.45000
# THB: 1.00120
# PHP: 0.61740
# IDR: 0.00238
# EUR: 34.78000
# KRW: 0.02538
# VND: 0.00145
# MYR: 7.79100
# CNY: 4.55700

# %% [markdown]
# 之前做的爬文程式

# %%
import urllib.request as req
import requests as re
import bs4

Homepage_url = 'https://www.novel543.com/1114494410/dir'
path = {"User-Agent" : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36'}
request = req.Request(Homepage_url,headers=path)

with req.urlopen(request) as res:
    data = res.read().decode('utf-8')

content = bs4.BeautifulSoup(data, "html.parser")
temp = content.find("ul", class_="flex one two-700 three-900 all")
story_url = temp.find_all("a")

with open("隱世魔尊，女帝帶娃上門求負責.txt", "w", encoding="UTF-8") as t:
    count = 0
    for title in story_url:
        print(title.get_text())
        if count > 350:
            print(title.get_text(), file=t)
        link = "https://www.novel543.com" + title.get("href")
        next_link = link[:-5] + "_2.html"
        link_data = re.get(link, headers=path)
        next_link_data = re.get(next_link, headers=path)
        link_data.encoding = link_data.apparent_encoding
        link_data = link_data.text
        next_link_data.encoding = next_link_data.apparent_encoding
        next_link_data = next_link_data.text
        link_content = bs4.BeautifulSoup(link_data, "html.parser")
        next_link_content = bs4.BeautifulSoup(next_link_data, "html.parser")
        link_article = link_content.find("div", class_="content py-5")
        next_link_article = next_link_content.find("div", class_="content py-5")
        for i in link_article.find_all('p'):
            match i.get_text():
                case '溫馨提示: 點下一頁會跳轉到其他網站的情況, 也許可能應該已經解決了(我也不太確定), 如果大家還有發現這種情況,請用底部的「章節報錯」或「聯絡我們」告知, 感謝!':
                    continue
                case '如果覺得本書不錯, 避免下次找不到, 請記得加入書架哦':
                    continue
                case '':
                    continue
                case _:
                    print(i.get_text(), file=t)
                    print('\n', file=t)
        for j in next_link_article.find_all('p'):
            match j.get_text():
                case '溫馨提示: 點下一頁會跳轉到其他網站的情況, 也許可能應該已經解決了(我也不太確定), 如果大家還有發現這種情況,請用底部的「章節報錯」或「聯絡我們」告知, 感謝!':
                    continue
                case '如果覺得本書不錯, 避免下次找不到, 請記得加入書架哦':
                    continue
                case '':
                    continue
                case _:
                    print(j.get_text(), file=t)
                    print('\n', file=t)
        count = count + 1
# Out:
# 第0章 序章
# 第1章 娘親帶你去找你爹爹
# 第2章 我可沒說我不負責！
# 第3章 爹爹可想我們家夜夜了
# 第4章 我娘子挺迷人的~
# 第5章 那個男人，又回來了！
# 第6章 他怎麼又回來了！
# 第7章 我覺得你還不行
# 第8章 這可比做魔尊的時候有意思多了
# 第9章 娘子你喜歡，那就夠了
# 第10章 他只是一介凡人，不能怪他...
# 第11章 為夫不會吃了你的~
# 第12章 下輩子注意點就行
# 第13章 真的只是為了孩子而已
# 第14章 只是有點上火而已…
# 第15章 為夫向來都是裸睡的
# 第16章 仙界女帝不做也罷
# 第17章 怎麼又有人來了
# 第18章 那你今日，你必死！
# 第19章 爹爹給夜夜變個魔法
# 第20章 在那之前，我會先殺了你
# 第21章 你們觸及了本尊的逆鱗！
# 第22章 這位前輩人還怪好的
# 第23章 你媽的！說不說！
# 第24章 你現在可不許死，否則俺弄死你
# 第25章 大人，不能再注入了！
# 第26章 你們老祖不會回來了
# 第27章 下次有事還找你
# 第28章 這可是他的岳父大人啊！
# 第29章 叫不醒的寧夜辰
# 第30章 為夫其實非常恐高
# 第31章 我娘子還在等我回去，趕時間
# 第32章 你出完招了？那該我了
# 第33章 魔尊愛誰當誰當，反正我不當
# 第34章 部下太忠誠和狂熱也不好
# 第35章 娘子說的對！
# 第36章 娘子還是太心善了
# 第37章 一看就是個很溫柔的人
# 第38章 是啊，太可怕了！
# 第39章 我夫君不是你能羞辱的！
# 第40章 把他第三條腿廢了
# 第41章 大人有令，你得死！
# 第42章 俺重新再來
# 第43章 娘子吃東西的時候也真美
# 第44章 這些應該夠了
# 第45章 略懂略懂~
# 第46章 這絕不是偷窺！
# 第47章 世代為醫，救死扶傷！
# 第48章 真不愧是爹爹的小寶貝！
# 第49章 你摸到前面幹嘛！
# 第50章 魔尊大人他成婚了！
# 第51章 魔尊大人有后了！
# 第52章 為夫的手也有點冷...
# 第53章 唯有大人好可怕…
# 第54章 是的，你死定了！
# 第55章 家中財物自然是歸娘子管
# 第56章 這對夫婦定然非凡…
# 第57章 不可能是他...！
# ...
